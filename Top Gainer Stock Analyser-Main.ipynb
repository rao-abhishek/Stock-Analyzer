# %%
import numpy as np 
import pandas as pd
from pandas_datareader import data as pdr 
import pandas_datareader as web
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import mplfinance as mpf
# Market Data 
import yfinance as yf
from datetime import date
from datetime import datetime as dt
from datetime import timedelta
from datetime import datetime
import datetime
import csv
import pandas_ta as ta

# Graphing / Visualization 
import plotly.graph_objs as go

# %%
#Importing Listed Companies data

headcheck = 0
tg_day=3
tg_month=10
tg_year=2022
tg_date = datetime.datetime(tg_year, tg_month, tg_day)
top_gainers_file_path = "Stock Analysis Result/add- StochRSI, Top Gainers Possibilities.csv";
#C:\Users\Abhishek Rao\ML Project\Beta-ML-Project-master\Beta-ML-Project-master\ALL NSE STOCKS
lcd = pd.read_csv('file:///C:/Users/Abhishek%20Rao/ML%20Project/Beta-ML-Project-master/Beta-ML-Project-master/ALL%20NSE%20STOCKS/T20-GL-gainers-allSec-'+tg_date.strftime("%d-%b-%Y")+'.csv')

lcd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\urllib\request.py in open_local_file(self, req)
#    1505         try:
# -> 1506             stats = os.stat(localfile)
#    1507             size = stats.st_size
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\Abhishek Rao\\ML Project\\Beta-ML-Project-master\\Beta-ML-Project-master\\ALL NSE STOCKS\\T20-GL-gainers-allSec-26-Sep-2022.csv'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28904\794493190.py in <module>
#       8 top_gainers_file_path = "Stock Analysis Result/add- Supertrend, 200DEMA, Top Gainers Possibilities.csv";
#       9 #C:\Users\Abhishek Rao\ML Project\Beta-ML-Project-master\Beta-ML-Project-master\ALL NSE STOCKS
# ---> 10 lcd = pd.read_csv('file:///C:/Users/Abhishek%20Rao/ML%20Project/Beta-ML-Project-master/Beta-ML-Project-master/ALL%20NSE%20STOCKS/T20-GL-gainers-allSec-'+tg_date.strftime("%d-%b-%Y")+'.csv')
#      11
#      12 lcd
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     612         compression=compression,
#     613         mode=mode,
# --> 614         storage_options=storage_options,
#     615     )
#     616
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     310         # assuming storage_options is to be interpreted as headers
#     311         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 312         with urlopen(req_info) as req:
#     313             content_encoding = req.headers.get("Content-Encoding", None)
#     314             if content_encoding == "gzip":
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     210     import urllib.request
#     211
# --> 212     return urllib.request.urlopen(*args, **kwargs)
#     213
#     214
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\urllib\request.py in file_open(self, req)
#    1482                 raise URLError("file:// scheme is supported only on localhost")
#    1483         else:
# -> 1484             return self.open_local_file(req)
#    1485
#    1486     # names for the localhost
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\urllib\request.py in open_local_file(self, req)
#    1521                 return addinfourl(open(localfile, 'rb'), headers, origurl)
#    1522         except OSError as exp:
# -> 1523             raise URLError(exp)
#    1524         raise URLError('file not on local host')
#    1525
#
# URLError: <urlopen error [WinError 2] The system cannot find the file specified: 'C:\\Users\\Abhishek Rao\\ML Project\\Beta-ML-Project-master\\Beta-ML-Project-master\\ALL NSE STOCKS\\T20-GL-gainers-allSec-26-Sep-2022.csv'>

# %%
#Importing the Top Gainers Possibilities

try:
    with open(top_gainers_file_path, mode='r') as infile:
        reader = csv.reader(infile)
        next(reader, None)  # skip the headers
        possibilities_count = {rows[0]:rows[1] for rows in reader}
    
    print(possibilities_count)
except:
    possibilities_count={}
    print("File Not Found Error")
# Out:
# {'Red Histogram, Price Above 200 EMA, MACD Parallel Above, EMA Decreasing, Green Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Green Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '4', 'Green Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Above 200 EMA, MACD Expanding Below, EMA Increasing, Red Supertrend, Price Above 200 DEMA, 200 EMA Below 200 DEMA Expanding': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '8', 'Red Histogram, Price Above 200 EMA, MACD Parallel Below, EMA Increasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Parallel Above, EMA Decreasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '7', 'Red Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '3', 'Red Histogram, Price Below 200 EMA, MACD Intersecting Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '6', 'Green Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '2', 'Green Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '2', 'Green Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Green Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Above 200 EMA, MACD Expanding Above, EMA Increasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Expanding': '2', 'Green Histogram, Price Above 200 EMA, MACD Expanding Above, EMA Increasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Below 200 DEMA Expanding': '2', 'Green Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Above, EMA Decreasing, Green Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '3', 'Green Histogram, Price Above 200 EMA, MACD Intersecting Above, EMA Increasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Below 200 DEMA Expanding': '3', 'Red Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Above 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Increasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Expanding': '2', 'Green Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Green Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Parallel Above, EMA Decreasing, Green Supertrend, Price Below 200  ...

# %%
#Taking the Symbols from the dataframe to list
company_list=[]
company_list = list(lcd['Symbol'])
#print(company_list)

#MACRO
START_SL = 0
END_SL = len(company_list)
SOUND = 0

# %%
yf.pdr_override()

# %%
#THE GRAND LOOP 
for si in range(START_SL,END_SL):
    stock_symbol=company_list[si]
    stock_symbol+='.NS'
    print(stock_symbol)
    STOCK=stock_symbol
    PERIOD='60d'
    INTERVAL='15m'
    df = yf.download(tickers=STOCK, period=PERIOD, interval=INTERVAL)
    df.index
    
    if(len(df)==0):
        print("Stock "+STOCK+" Skipped due to No Data Found")
        continue
      
    try:
        #Check gainer or loser
        if(float(df['Close'][-1:])<float(df['Open'][-18:-17])):
            print("Loss: ",end="")
            print(float(df['Close'][-1:])-float(df['Open'][-18:-17]))
            print("Stock Skipped",end="\n\n")
            
            continue
    except:
        print("Stock "+STOCK+" skipped Due to Insufficient Data")
        continue
        


    # Get the 200 EMA of the closing price
    ema200 = df['Close'].ewm(span=200, adjust=False, min_periods=200).mean()

    # Get the 26-day EMA of the closing price
    k = df['Close'].ewm(span=12, adjust=False, min_periods=12).mean()
    # Get the 12-day EMA of the closing price
    d = df['Close'].ewm(span=26, adjust=False, min_periods=26).mean()
    # Subtract the 26-day EMA from the 12-Day EMA to get the MACD
    macd = k - d
    # Get the 9-Day EMA of the MACD for the Trigger line
    macd_s = macd.ewm(span=9, adjust=False, min_periods=9).mean()
    # Calculate the difference between the MACD - Trigger for the Convergence/Divergence value
    macd_h = macd - macd_s
    # Add all of our new values for the MACD to the dataframe
    df['Macd'] = df.index.map(macd)
    df['Macd histogram'] = df.index.map(macd_h)
    df['Macd Signal'] = df.index.map(macd_s)
    df['200 EMA'] = df.index.map(ema200)

    df
    
    #Get Supertrend Data
    #print(ta.supertrend(high=df['High'],low=df['Low'],close=df['Close'],period=12,multiplier=3))
    try:
        df['Supertrend'] = ta.supertrend(high=df['High'],low=df['Low'],close=df['Close'],period=12,multiplier=3)['SUPERT_7_3.0']
    except:
        print("Stock "+STOCK+" skipped Due to Insufficient Data")
        continue
    #print(df)
    
    #Get Stochastic RSI Data
    #print(ta.stochrsi(df['Close'],k=3,d=3, length=14,rsi_length=14))
    try:
        df['Stochastic RSI']=ta.stochrsi(df['Close'],k=3,d=3, length=14,rsi_length=14)['STOCHRSId_14_14_3_3']
    except:
        print("Stock "+STOCK+" skipped Due to Insufficient Data")
        continue
        
    
    mpf.plot(df[-100:], figratio=(50,25),
            type='candle',
            title=STOCK+' Price',
            volume=True,
            tight_layout=True,
            style='yahoo')
    #Get 200 DEMA
    
    dema200 = ema200*2 - ema200.ewm(span=200, adjust=False, min_periods=200).mean()
    df['200 DEMA'] = df.index.map(dema200)
    
    print(stock_date)
    if(int(stock_date.strftime("%w"))==1):
        d = stock_date - timedelta(days=3)
    else:
        d = stock_date - timedelta(days=1)
    print(d)
    start_date = datetime.datetime(int(d.strftime("%Y")), int(d.strftime("%m")), int(d.strftime("%d")), 14, 45,0)
    #print(start_date)
    end_date = datetime.datetime(int(d.strftime("%Y")), int(d.strftime("%m")), int(d.strftime("%d")), 15, 15,0)
    #print(end_date)

    #Characteristics analysis
    val_data = df.loc[start_date:end_date]

    val_data

    #GREEN OR RED

    result=[]


    negative_count=0
    positive_count=0
    for i in range(len(val_data)):
        if(val_data['Macd histogram'][i]<0):
            negative_count+=1
        elif(val_data['Macd histogram'][i]>0):
            positive_count+=1

    if(positive_count>negative_count):
        result.append("Green Histogram")
    else:
        result.append("Red Histogram")
    


    #Above or Below 200EMA
    cc=0
    for i in range(len(val_data)):
        if(val_data['Close'][i]>val_data['200 EMA'][i]):
            cc=1
            break
    if(cc==1):
        result.append("Price Above 200 EMA")
    else:
        result.append("Price Below 200 EMA")
    
    

    #Macd Intersecting Above or Intersecting Below or Expanding Above or Expanding Below
    def is_df_ascend_sorted(arr):
        c=0
        for i in range(len(arr)-1):
            if(abs(arr[i])>abs(arr[i+1])):
                c=1
        if(c==1):
            return False
        else:
            return True

    def is_df_descend_sorted(arr):
        c=0
        for i in range(len(arr)-1):
            if(abs(arr[i])<abs(arr[i+1])):
                c=1
        if(c==1):
            return False
        else:
            return True
            
            
    
    try:
        if(is_df_ascend_sorted(val_data['Macd histogram'])):
            if(val_data['Macd'][0]<0 or val_data['Macd Signal'][0]<0):
                result.append("MACD Expanding Below")
            else:
                result.append("MACD Expanding Above")
        elif(is_df_descend_sorted(val_data['Macd histogram'])):
            if(val_data['Macd'][0]<0 or val_data['Macd Signal'][0]<0):
                result.append("MACD Intersecting Below")
            else:
                result.append("MACD Intersecting Above")
            
        else:
            if(val_data['Macd'][0]<0 or val_data['Macd Signal'][0]<0):
                result.append("MACD Parallel Below")
            else:
                result.append("MACD Parallel Above")
    except:
        print("Stock "+STOCK+" skipped Due to Insufficient Data")
        continue
        
        
        
        

    #EMA Decreasing or EMA Increasing
    if(is_df_ascend_sorted(val_data['200 EMA'])):
        result.append("EMA Increasing")
    else:
        result.append("EMA Decreasing")

    #Red Supertrend or Green Supertrend
    
    if(int(val_data['Supertrend'][-1:])<int(val_data['Close'][-1:])):
        result.append('Green Supertrend')
    else:
        result.append('Red Supertrend')
    
    #Price Above 200 DEMA or Price Below 200 DEMA
    try:
        if(int(val_data['200 DEMA'][-1:])>int(val_data['Close'][-1:])):
            result.append("Price Below 200 DEMA")
        else:
            result.append("Price Above 200 DEMA")
    except:
        print("Stock "+STOCK+" skipped Due to Insufficient Data")
        continue
    
    #200 EMA Above 200 DEMA Expanding or 200 EMA Above 200 DEMA Intersecting or 200 EMA Below 200 DEMA Expanding or 200 EMA Below 200 DEMA Intersecting
        
    if(int(val_data['200 EMA'][-1:])>int(val_data['200 DEMA'][-1:])):
        if(is_df_ascend_sorted(val_data['200 EMA']-val_data['200 DEMA'])):
            result.append("200 EMA Above 200 DEMA Expanding")
        else:
            result.append("200 EMA Above 200 DEMA Intersecting")
    else:
        if(is_df_ascend_sorted(val_data['200 EMA']-val_data['200 DEMA'])):
            result.append("200 EMA Below 200 DEMA Expanding")
        else:
            result.append("200 EMA Below 200 DEMA Intersecting")
          
    #O2C Profit or O2C Loss
    try:
        if(float(df['Close'][-1:])>float(df['Open'][-18:-17])):
            result.append("O2C Profit")
        else:
            result.append("O2C Loss")
    except:
        print("Stock "+STOCK+" skipped Due to Insufficient Data")
        continue   
    
    #Stochastic RSI Increasing or Stochastic RSI Decreasing
    
    try:
        if(is_df_ascend_sorted(val_data['Stochastic RSI'])):
            result.append("Stochastic RSI Increasing")
        else:
            result.append("Stochastic RSI Decreasing")
    except:
        print("Stock "+STOCK+" skipped Due to Insufficient Data")
        continue

    print(si, end=". ")
    print(STOCK,end=": ")
    print(result,end="\n\n")
    
    
    possibilities_count[', '.join(map(str, result))]=int(possibilities_count.get(', '.join(map(str, result)),  0))+1
# Out:
# BHARATGEAR.NS
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# 0. BHARATGEAR.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Parallel Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Below 200 DEMA Intersecting']
#
# SILLYMONKS.NS
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 1. SILLYMONKS.NS: ['Red Histogram', 'Price Below 200 EMA', 'MACD Parallel Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Below 200 DEMA Intersecting']
#
# HCC.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 2. HCC.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Parallel Below', 'EMA Decreasing', 'Red Supertrend', 'Price Above 200 DEMA', '200 EMA Below 200 DEMA Expanding']
#
# LIBERTSHOE.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 3. LIBERTSHOE.NS: ['Green Histogram', 'Price Above 200 EMA', 'MACD Parallel Below', 'EMA Increasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Below 200 DEMA Intersecting']
#
# JTEKTINDIA.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 4. JTEKTINDIA.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# SEPC.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 5. SEPC.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Above 200 DEMA', '200 EMA Below 200 DEMA Expanding']
#
# PRUDENT.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 6. PRUDENT.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# FILATEX.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 7. FILATEX.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# SBCL.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 8. SBCL.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# GUJAPOLLO.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 9. GUJAPOLLO.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# ARCHIDPLY.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 10. ARCHIDPLY.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# ARVINDFASN.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 11. ARVINDFASN.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Parallel Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Below 200 DEMA Intersecting']
#
# AIROLAM.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 12. AIROLAM.NS: ['Green Histogram', 'Price Above 200 EMA', 'MACD Intersecting Below', 'EMA Increasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Below 200 DEMA Intersecting']
#
# RENUKA.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 13. RENUKA.NS: ['Green Histogram', 'Price Above 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Below 200 DEMA Intersecting']
#
# PRAKASHSTL.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 14. PRAKASHSTL.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Parallel Below', 'EMA Decreasing', 'Red Supertrend', 'Price Above 200 DEMA', '200 EMA Below 200 DEMA Expanding']
#
# STCINDIA.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 15. STCINDIA.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# SRHHYPOLTD.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 16. SRHHYPOLTD.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# RAJRATAN.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 17. RAJRATAN.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# MARALOVER.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 18. MARALOVER.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
#
# ASTERDM.NS
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
# [*********************100%***********************]  1 of 1 completed
# 2022-09-27 00:00:00
# 19. ASTERDM.NS: ['Green Histogram', 'Price Below 200 EMA', 'MACD Intersecting Below', 'EMA Decreasing', 'Red Supertrend', 'Price Below 200 DEMA', '200 EMA Above 200 DEMA Expanding']
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:76: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.

# %%
print(possibilities_count)
print(len(possibilities_count))
# Out:
# {'Red Histogram, Price Above 200 EMA, MACD Parallel Above, EMA Decreasing, Green Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Green Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '4', 'Green Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Above 200 EMA, MACD Expanding Below, EMA Increasing, Red Supertrend, Price Above 200 DEMA, 200 EMA Below 200 DEMA Expanding': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '8', 'Red Histogram, Price Above 200 EMA, MACD Parallel Below, EMA Increasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Parallel Above, EMA Decreasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '7', 'Red Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': 4, 'Red Histogram, Price Below 200 EMA, MACD Intersecting Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '6', 'Green Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '2', 'Green Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '2', 'Green Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Green Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Above 200 EMA, MACD Expanding Above, EMA Increasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Expanding': '2', 'Green Histogram, Price Above 200 EMA, MACD Expanding Above, EMA Increasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Below 200 DEMA Expanding': '2', 'Green Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Above, EMA Decreasing, Green Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Above 200 DEMA Expanding': '3', 'Green Histogram, Price Above 200 EMA, MACD Intersecting Above, EMA Increasing, Green Supertrend, Price Above 200 DEMA, 200 EMA Below 200 DEMA Expanding': '3', 'Red Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Above 200 DEMA, 200 EMA Above 200 DEMA Expanding': '2', 'Red Histogram, Price Above 200 EMA, MACD Parallel Below, EMA Decreasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Expanding Below, EMA Increasing, Red Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Expanding': '2', 'Green Histogram, Price Below 200 EMA, MACD Parallel Below, EMA Decreasing, Green Supertrend, Price Below 200 DEMA, 200 EMA Below 200 DEMA Intersecting': '2', 'Red Histogram, Price Below 200 EMA, MACD Parallel Above, EMA Decreasing, Green Supertrend, Price Below 200 DE ...
# 50

# %%
#Writing Possibilites into CSV Files
pos_head_check=0
target_filename_pos = top_gainers_file_path
header = pd.DataFrame(columns=['Possibilities','Occurence'])
for key,value in possibilities_count.items():
    row = pd.DataFrame([[key,value]], columns=['Possibilities','Occurence'])
    if(pos_head_check==0):
        row.to_csv(target_filename_pos , index=False)
        pos_head_check=1
    else:
        row.to_csv(target_filename_pos, header=False,mode="a" , index=False)
